# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn
import numpy as np

# %%
x = np.random.random((9,2)) * np.random.choice([-1,1],(9,2))

# %%
fig,ax = plt.subplots(1,1)
ax.scatter(x[:,0],x[:,1],c=seaborn.color_palette('Set1',n_colors=9),s=50)
for i in xrange(len(x)):
    ax.plot([0,x[i,0]],[0,x[i,1]],c='k',alpha=.25)

# %%
from sklearn.preprocessing import Normalizer
nrm = Normalizer('l2')
normed = nrm.fit_transform(x)

# %%
fig,ax = plt.subplots(1,1)
ax.scatter(normed[:,0],normed[:,1],c=seaborn.color_palette('Set1',n_colors=9),s=50)
for i in xrange(len(normed)):
    for j in xrange(len(normed)):
        ax.plot([normed[i,0],normed[j,0]],[normed[i,1],normed[j,1]],c='k',alpha=.1)

# %%
ax.plot?
